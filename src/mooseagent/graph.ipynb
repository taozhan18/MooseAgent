# %%
from IPython.display import Image, display
from langgraph.types import Command
from langgraph.checkpoint.memory import MemorySaver
from dotenv import load_dotenv
from dotenv import load_dotenv
import sys

sys.path.append("../")
load_dotenv()
from self_rag.graph import RAG
import os

load_dotenv()
from graph import graph
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# 加载已存在的向量库...
# e:\vscode\python\Agent\langgraph_learning\mooseagent\src\mooseagent\..\mooseagent\self_rag\self_rag.py:43: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore = Chroma(

# %%
from dotenv import load_dotenv
import sys

sys.path.append("../")
load_dotenv()
# Out:
# True

# %%
display(Image(graph.get_graph(xray=1).draw_mermaid_png()))

# %%
topic = """
Perform steady-state thermomechanical calculations for a Pressurized Water Reactor (PWR) fuel rod. The setup is as follows:
Geometric Conditions: The fuel pellet is made of UO₂ ceramic with a diameter of 8.192 mm; The cladding is made of Zr4 alloy with an inner diameter of 8.36 mm, an outer diameter of 9.5 mm, and a height of 3657 mm.
Boundary Conditions: Adiabatic boundary conditions are applied at the top and bottom; The right side is set as an isothermal boundary condition, with an inlet temperature of 293 K and an outlet temperature of 333 K. The temperature in between is linearly interpolated; The gap between the fuel pellet and the cladding is set with an internal pressure of 2 MPa.
Source Term: The volume heat generation rate in the fuel pellet is set as a cosine distribution along the axial direction and is uniform in the radial direction; The power is 0 at the top and bottom, and reaches a maximum of 2×10⁷ kW/m³ at the center.
Material Properties: Fuel Pellet Thermal Conductivity: 1/(11.8+0.0238*T) + 8.775*1e-13*T^3 W/(cm·°C), Fuel Pellet Thermal Expansion Coefficient: Isotropic, with the formula: 7.107e-6+5.16e-9*T+3.42e-13*T^2(°C^(-1)); Cladding Thermal Conductivity: 0.15W/(cm·°C); Cladding Thermal Expansion Coefficient: 5.5e-6(°C^(-1)). In all formulas, T represents temperature in °C.
"""

# %%
def stream_graph_updates(user_input: str):
    for event in graph.stream({"requirement": user_input}):
        for value in event.values():
            print(value)

# %%
topic = """
Perform steady-state thermomechanical calculations for a Pressurized Water Reactor (PWR) fuel rod. The setup is as follows:
Geometric Conditions: The fuel pellet is made of UO₂ ceramic with a diameter of 8.192 mm; The cladding is made of Zr4 alloy with an inner diameter of 8.36 mm, an outer diameter of 9.5 mm, and a height of 3657 mm.
Boundary Conditions: Adiabatic boundary conditions are applied at the top and bottom; The right side is set as an isothermal boundary condition, with an inlet temperature of 293 K and an outlet temperature of 333 K. The temperature in between is linearly interpolated; The gap between the fuel pellet and the cladding is set with an internal pressure of 2 MPa.
Source Term: The volume heat generation rate in the fuel pellet is set as a cosine distribution along the axial direction and is uniform in the radial direction; The power is 0 at the top and bottom, and reaches a maximum of 2×10⁷ kW/m³ at the center.
Material Properties: Fuel Pellet Thermal Conductivity: 1/(11.8+0.0238*T) + 8.775*1e-13*T^3 W/(cm·°C), Fuel Pellet Thermal Expansion Coefficient: Isotropic, with the formula: 7.107e-6+5.16e-9*T+3.42e-13*T^2(°C^(-1)); Cladding Thermal Conductivity: 0.15W/(cm·°C); Cladding Thermal Expansion Coefficient: 5.5e-6(°C^(-1)). In all formulas, T represents temperature in °C.
"""
stream_graph_updates(topic)
# Out:
# {'overall_description': 'Perform steady-state thermomechanical calculations for a Pressurized Water Reactor (PWR) fuel rod with specified geometric, boundary, source term, and material properties. The simulation will analyze the thermal and mechanical behavior of the fuel rod under given conditions, ensuring accurate representation of the physical phenomena involved.', 'structured_requirements': 'Mesh: cylindrical geometry with dimensions based on fuel rod specifications; Physical variables: temperature, stress; Physical equations: steady-state heat transfer and mechanical equilibrium; Boundary Conditions: adiabatic at top and bottom, isothermal on the right side; Materials: UO₂ (thermal conductivity, thermal expansion coefficient) and Zr4 alloy (thermal conductivity, thermal expansion coefficient); Executioner: steady-state solver with appropriate preconditioner.', 'retrieve_tasks': ['Determine the appropriate mesh size and type for the fuel rod geometry', 'Identify the coordinate system suitable for cylindrical geometry', 'Clarify the physical equations governing steady-state heat transfer and mechanical stress', 'Define the specific locations and types of boundary conditions (adiabatic, isothermal)', 'List the material parameters required for UO₂ and Zr4 alloy, including elastic modulus and thermal properties', 'Specify the execution parameters for the simulation, including solver type and preconditioner', 'Investigate the implementation of a cosine distribution for the volume heat generation rate']}
# {'grade_architect': 'pass', 'feedback_architect': "The structured simulation requirements accurately reflect the user's request for steady-state thermomechanical calculations for a PWR fuel rod. The mesh, physical variables, equations, boundary conditions, materials, and executioner details are all aligned with the user's specifications. Therefore, the structured simulation requirements meet the user's requirements."}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 8
#       1 topic = """
#       2 Perform steady-state thermomechanical calculations for a Pressurized Water Reactor (PWR) fuel rod. The setup is as follows:
#       3 Geometric Conditions: The fuel pellet is made of UO₂ ceramic with a diameter of 8.192 mm; The cladding is made of Zr4 alloy with an inner diameter of 8.36 mm, an outer diameter of 9.5 mm, and a height of 3657 mm.
#    (...)
#       6 Material Properties: Fuel Pellet Thermal Conductivity: 1/(11.8+0.0238*T) + 8.775*1e-13*T^3 W/(cm·°C), Fuel Pellet Thermal Expansion Coefficient: Isotropic, with the formula: 7.107e-6+5.16e-9*T+3.42e-13*T^2(°C^(-1)); Cladding Thermal Conductivity: 0.15W/(cm·°C); Cladding Thermal Expansion Coefficient: 5.5e-6(°C^(-1)). In all formulas, T represents temperature in °C.
#       7 """
# ----> 8 stream_graph_updates(topic)
#
# Cell In[4], line 2, in stream_graph_updates(user_input)
#       1 def stream_graph_updates(user_input: str):
# ----> 2     for event in graph.stream({"requirement": user_input}):
#       3         for value in event.values():
#       4             print(value)
#
# File d:\Anaconda\envs\crewai-env\Lib\site-packages\langgraph\pregel\__init__.py:1779, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1773     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1774     # computation proceeds in steps, while there are channel updates.
#    1775     # Channel updates from step N are only visible in step N+1
#    1776     # channels are guaranteed to be immutable for the duration of the step,
#    1777     # with channel updates applied only at the transition between steps.
#    1778     while loop.tick(input_keys=self.input_channels):
# -> 1779         for _ in runner.tick(
#    1780             loop.tasks.values(),
#    1781             timeout=self.step_timeout,
#    1782             retry_policy=self.retry_policy,
#    1783             get_waiter=get_waiter,
#    1784         ):
#    1785             # emit output
#    1786             yield from output()
#    1787 # emit output
#
# File d:\Anaconda\envs\crewai-env\Lib\site-packages\langgraph\pregel\runner.py:230, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     228 t = tasks[0]
#     229 try:
# --> 230     run_with_retry(
#     231         t,
#     232         retry_policy,
#     233         configurable={
#     234             CONFIG_KEY_SEND: partial(writer, t),
#     235             CONFIG_KEY_CALL: partial(call, t),
#     236         },
#     237     )
#     238     self.commit(t, None)
#     239 except Exception as exc:
#
# File d:\Anaconda\envs\crewai-env\Lib\site-packages\langgraph\pregel\retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\Anaconda\envs\crewai-env\Lib\site-packages\langgraph\utils\runnable.py:546, in RunnableSeq.invoke(self, input, config, **kwargs)
#     542 config = patch_config(
#     543     config, callbacks=run_manager.get_child(f"seq:step:{i + 1}")
#     544 )
#     545 if i == 0:
# --> 546     input = step.invoke(input, config, **kwargs)
#     547 else:
#     548     input = step.invoke(input, config)
#
# File d:\Anaconda\envs\crewai-env\Lib\site-packages\langgraph\utils\runnable.py:310, in RunnableCallable.invoke(self, input, config, **kwargs)
#     308 else:
#     309     context.run(_set_config_context, config)
# --> 310     ret = context.run(self.func, *args, **kwargs)
#     311 if isinstance(ret, Runnable) and self.recurse:
#     312     return ret.invoke(input, config)
#
# File e:\vscode\python\Agent\langgraph_learning\mooseagent\src\mooseagent\graph.py:155, in generate_inpcard(state, config)
#     153 conbine = ""
#     154 for task in retrieve_tasks:
# --> 155     result = query_module(task)
#     156     conbine += f"The task is: {task}\nThe result is: {result}\n\n"
#     157     if result is not None:
#
# File e:\vscode\python\Agent\langgraph_learning\mooseagent\src\mooseagent\graph.py:131, in query_module(module)
#     129 def query_module(module):
#     130     """同步查询每个模块的信息"""
# --> 131     query = f"please find information how to achieve the following description in {module.name}: {module.description}"
#     132     results = []
#     133     # 使用同步调用
#
# AttributeError: 'str' object has no attribute 'name'
# During task with name 'generate_inpcard' and id '258de650-4ff8-48e0-0a4b-e9dc09e15e4a'

# %%
from self_rag.graph import RAG

docs = RAG.invoke({"question": topic})
# Out:
# ---RETRIEVE ITERATION: 1---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: ALL DOCUMENTS ARE NOT RELEVANT TO QUESTION, TRANSFORM QUERY---
# ---TRANSFORM QUERY---
# ---RETRIEVE ITERATION: 2---
# ---CHECK DOCUMENT RELEVANCE TO QUESTION---
# ---GRADE: DOCUMENT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---GRADE: DOCUMENT NOT RELEVANT---
# ---ASSESS GRADED DOCUMENTS---
# ---DECISION: GENERATE---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---GENERATE---
# ---CHECK HALLUCINATIONS---
# ---DECISION: GENERATION IS NOT GROUNDED IN DOCUMENTS, RE-TRY---
# ---------------------------------------------------------------------------
# GraphRecursionError                       Traceback (most recent call last)
# Cell In[6], line 3
#       1 from self_rag.graph import RAG
# ----> 3 docs = RAG.invoke({"question": topic})
#
# File d:\Anaconda\envs\crewai-env\Lib\site-packages\langgraph\pregel\__init__.py:2124, in Pregel.invoke(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, **kwargs)
#    2122 else:
#    2123     chunks = []
# -> 2124 for chunk in self.stream(
#    2125     input,
#    2126     config,
#    2127     stream_mode=stream_mode,
#    2128     output_keys=output_keys,
#    2129     interrupt_before=interrupt_before,
#    2130     interrupt_after=interrupt_after,
#    2131     debug=debug,
#    2132     **kwargs,
#    2133 ):
#    2134     if stream_mode == "values":
#    2135         latest = chunk
#
# File d:\Anaconda\envs\crewai-env\Lib\site-packages\langgraph\pregel\__init__.py:1799, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1790 if loop.status == "out_of_steps":
#    1791     msg = create_error_message(
#    1792         message=(
#    1793             f"Recursion limit of {config['recursion_limit']} reached "
#    (...)
#    1797         error_code=ErrorCode.GRAPH_RECURSION_LIMIT,
#    1798     )
# -> 1799     raise GraphRecursionError(msg)
#    1800 # set final channel values as run output
#    1801 run_manager.on_chain_end(loop.output)
#
# GraphRecursionError: Recursion limit of 25 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/GRAPH_RECURSION_LIMIT

# %%
docs
# Out:
# {'question': 'find information about FunctorMaterials',
#  'generation': 'Sorunuza yanıt olarak, **FunctorMaterials** ile ilgili detaylı bilgi şunlardır:\n\n### FunctorMaterials Nedir?\n- **FunctorMaterials**, MOOSE (Multiphysics Object-Oriented Simulation Environment) çerçevesinde kullanılan özel bir malzeme türüdür. Bu malzemeler, materyal özelliklerini "on-the-fly" (anlık olarak) değerlendirir. \n- Aynı zamanda, diğer özelliklerin hesaplamalarını da "on-the-fly" gerçekleştirebilmektedir. \n\n### Kullanım Amaçları\n- **Producer/Consumer Modeli**: \n  FunctorMaterials, bir üretici-tüketici modeli izleyerek, **Functor Material Properties** (funktör malzeme özellikleri) üretir. Daha sonra bu özellikler, çekirdekler, sınır koşulları, diğer funktör malzemeler vb. gibi yapılar tarafından tüketilir.\n- **Veri Türleri**: \n  Scalar (skaler), vector (vektör), tensor (tensor) ve otomatik türevlendirme sürümlerini içeren geniş bir veri tipi yelpazesini destekler.\n\n### Özellikler\n1. **Hafıza Ön Belleğe Alma (Caching)**:\n    - Tüm FunctorMaterials belli bir oranda ön bellekleme (caching) destekler. Bu, maliyetli malzeme özelliği hesaplamalarından kaçınmayı sağlar. Ancak bu ön bellekleme varsayılan olarak kapalıdır çünkü hafıza maliyetleri meydana getirebilir.\n  \n2. **Uyumluluk**:\n    - Funktör malzeme özellikleri genellikle düzenli malzeme özellikleri ile doğrudan uyumlu değildir. Eğer bu iki sistemin uyumlu çalışması gerekirse, bir **MaterialFunctorConverter.md** kullanılmalıdır.\n\n3. **Hata Ayıklama (Debugging)**:\n    - Eğer bir funktör eksik raporlanırsa, yapılan simülasyonda **Debug/!param** parametresi ile detaylı bilgi alınabilir.\n\n### Geliştirme ile İlgili Bilgiler\n- **Eklenen Özellikler**:\n  Yeni bir funktör özelliği eklemek için:\n  ```\n  addFunctorProperty<TYPE>\n  ```\n  Komutunu kullanabilirsiniz. Burada `TYPE`, Real, ADReal, RealVectorValue gibi türler olabilir.\n  \n- **Mevcut Özellikleri Almak**:\n  Mevcut bir funktör malzeme özelliğini almak için:\n  ```\n  getFunctor<TYPE>\n  ```\n\n### Önemli Notlar\n- FunctorMaterials, diğer birçok MOOSE alt sistemiyle birlikte çalışabilme kapasitesine sahiptir.\n- Eğer detaylı bilgi gerekiyorsa, **Functor system documentation** ve **MaterialFunctorConverter.md** dökümantasyonlarına başvurulabilir.\n\n---\n\n### Kaynaklar:\n- E:\\\\vscode\\\\python\\\\Agent\\\\langgraph_learning\\\\mooseagent\\\\src\\\\database\\\\syntax.md',
#  'documents': [Document(metadata={'source': 'E:\\vscode\\python\\Agent\\langgraph_learning\\mooseagent\\src\\database\\syntax.md'}, page_content='Functor materials are a special kind of materials used for on-the-fly material property evaluation. Please refer to the syntax page for FunctorMaterials for more information.\n\nAdvanced Topics\n\nEvaluation of Material Properties on Element Faces'),
#   Document(metadata={'source': 'E:\\vscode\\python\\Agent\\langgraph_learning\\mooseagent\\src\\database\\syntax.md'}, page_content='Using functor materials\n\nFollowing a producer/consumer model, FunctorMaterials produce functor material properties, which kernels, boundary conditions, other functor materials, etc, may consume. Both regular and functor material properties support a wide array of data types (scalar, vector, tensors, automatic differentiation versions of all of these). Functor materials, because they are evaluated on-the-fly and call other functors on-the-fly as well, do not require dependency ordering.\n\nAll functor materials support caching in some capacity. This can avoid expensive material property computations, but is disabled by default due to the potential memory cost. The reader is referred to the Functors caching documentation.\n\n!alert warning Functor material properties and regular material properties are generally +NOT+ compatible with each other. Functor material properties can only be used as regular material properties using a [MaterialFunctorConverter.md] to process them.'),
#   Document(metadata={'source': 'E:\\vscode\\python\\Agent\\langgraph_learning\\mooseagent\\src\\database\\syntax.md'}, page_content='Functor materials are created within the [FunctorMaterials] block.\n\n!alert note If a Functor is reported as missing by the simulation, and it was supposed to be created by a FunctorMaterial, you may use the Debug/!param parameter to get more information about what functors were created and requested.\n\nDeveloping with functor materials\n\nEvaluating functors\n\nSee the Functor system documentation for information on how to retrieve a functor material property value in a kernel, boundary condition, ... even another functor material property.\n\nCreating functor material properties\n\nThe functor material property system introduces APIs slightly different from the traditional material property system for declaring/adding and getting properties. To add a functor property:\n\naddFunctorProperty<TYPE>\n\nwhere TYPE can be anything such as Real, ADReal, RealVectorValue, ADRealVectorValue etc. To get a functor material property:\n\ngetFunctor<TYPE>'),
#   Document(metadata={'source': 'E:\\vscode\\python\\Agent\\langgraph_learning\\mooseagent\\src\\database\\syntax.md'}, page_content='!syntax list /Functions objects=False actions=False subsystems=True\n\n!syntax list /Functions objects=False actions=True subsystems=False\n\nFunctorMaterials\n\nMuch like regular materials declare regular material properties, functor materials declare functor material properties. Functor material properties are properties that are evaluated on-the-fly. Along with multiple other classes of MOOSE objects, they are Functors. This allows for the creation of objects with considerable inter-operability between systems.\n\nUsing functor materials')],
#  'iteration': 1}
