# %%
"""Define a custom Reasoning and Action agent.

Works with a chat model with tool calling support.
"""

import asyncio
import json
import sys
import os, re
from dotenv import load_dotenv
import subprocess

load_dotenv()
from langgraph.checkpoint.memory import MemorySaver

# sys.path.append("../")
sys.path.append(r"/home/zt/workspace/MooseAgent/src")
from tqdm import tqdm
from langchain_core.messages import AIMessage, SystemMessage, HumanMessage
from langchain_core.runnables import RunnableConfig
from langgraph.graph import START, END, StateGraph
from langgraph.prebuilt import ToolNode
from langchain.tools.retriever import create_retriever_tool
from langchain_community.vectorstores import Chroma, FAISS
from mooseagent.configuration import Configuration
from langchain_openai import OpenAIEmbeddings
from mooseagent.utils import (
    BGE_M3_EmbeddingFunction,
    tran_dicts_to_str,
    extract_files_and_descriptions,
    extract_sub_tasks,
)
from mooseagent.state1 import FlowState, ReviewState, OneFileState, ExtracterFileState, ArchitectState
from mooseagent.utils import load_chat_model
from mooseagent.prompts1 import (
    SYSTEM_ALIGNMENT_PROMPT,
    HUMAN_ALIGNMENT_PROMPT,
    SYSTEM_REVIEW_WRITER_PROMPT,
    SYSTEM_ARCHITECT_PROMPT,
    # HUMAN_ARCHITECT_PROMPT,
)
from mooseagent.write_module import bulid_writer_module
from langgraph.constants import Send
from langgraph.types import interrupt, Command
from langchain.tools.retriever import create_retriever_tool

config = RunnableConfig()
configuration = Configuration.from_runnable_config(config)
embedding_function = OpenAIEmbeddings() if configuration.embedding_function == "OPENAI" else BGE_M3_EmbeddingFunction()
batch_size = configuration.batch_size
top_k = configuration.top_k
json_file = configuration.rag_json_path
try:
    vectordb_input = FAISS.load_local(
        configuration.input_database_path, embedding_function, allow_dangerous_deserialization=True
    )
    retriever_input = vectordb_input.as_retriever(search_type="similarity", search_kwargs={"k": top_k})
    vectordb_dp = FAISS.load_local(
        configuration.dp_database_path, embedding_function, allow_dangerous_deserialization=True
    )
    retriever_dp = vectordb_dp.as_retriever(search_type="similarity", search_kwargs={"k": top_k})
    # define tools
    tools = [
        create_retriever_tool(
            retriever_input,
            "retrieve_moose_case",
            "Search and return information about MOOSE simulation cases that are relevant to the simulation case you are working on.",
        ),
        create_retriever_tool(
            retriever_dp,
            "retrieve_moose_dp",
            "Search and return information about the document of MOOSE app that are relevant to the simulation case you are working on.",
        ),
    ]
except Exception as e:
    print(f"Error loading vector database: {e}")

# %%
from typing import Annotated

from typing_extensions import TypedDict

from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from langgraph.prebuilt import ToolNode, tools_condition


class State(TypedDict):
    # Messages have the type "list". The `add_messages` function
    # in the annotation defines how this state key should be updated
    # (in this case, it appends messages to the list, rather than overwriting them)
    messages: Annotated[list, add_messages]

# %%
configuration = Configuration.from_runnable_config(config)


def helper(state: State):
    llm = load_chat_model(configuration.review_writer_model).bind_tools(tools)
    return {"messages": [llm.invoke(state["messages"])]}


# helper.invoke("How to define Dirichlet boundary condition in MOOSE?")

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("helper", helper)
tool_node = ToolNode(tools=tools)
graph_builder.add_node("tools", tool_node)
graph_builder.add_edge("tools", "helper")
graph_builder.set_entry_point("helper")
graph_builder.add_conditional_edges(
    "helper",
    tools_condition,
)
graph = graph_builder.compile()

# %%
from IPython.display import Image, display

try:
    display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
    # This requires some extra dependencies and is optional
    pass

# %%
def stream_graph_updates(user_input: str):
    for event in graph.stream({"messages": [{"role": "user", "content": user_input}]}):
        for value in event.values():
            print("Assistant:", value["messages"][-1].content)

# %%
answer = graph.invoke(
    {"messages": [{"role": "user", "content": "How to define Dirichlet boundary condition in MOOSE?"}]}
)

# %%
print(answer["messages"][3].content)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print(answer["messages"][4].content)
#
# IndexError: list index out of range

# %%
stream_graph_updates("How to define Dirichlet boundary condition in MOOSE?")
# Out:
# Assistant: To define a Dirichlet boundary condition in MOOSE, you typically use the `DirichletBC` class. This class is used to enforce a fixed value (usually zero) on a specified boundary for a given variable. Here’s a step-by-step guide on how to define a Dirichlet boundary condition in a MOOSE input file:
#
# ### 1. **Define the Variable:**
#    First, you need to define the variable on which you want to apply the Dirichlet boundary condition. This is usually done in the `Variables` block of the input file.
#
#    ```yaml
#    [Variables]
#      [u]
#        order = FIRST
#        family = LAGRANGE
#      []
#    []
#    ```
#
# ### 2. **Define the Boundary Condition:**
#    Next, you define the Dirichlet boundary condition in the `Kernels` block. You specify the variable, the boundary where the condition should be applied, and the value to be enforced.
#
#    ```yaml
#    [BCs]
#      [left]
#        type = DirichletBC
#        variable = u
#        boundary = left
#        value = 0
#      []
#    []
#    ```
#
#    - `type`: Specifies the type of boundary condition, which is `DirichletBC` in this case.
#    - `variable`: The variable to which the boundary condition is applied.
#    - `boundary`: The boundary where the condition is enforced. This can be a single boundary or a list of boundaries.
#    - `value`: The value to be enforced on the boundary. This is usually zero but can be any constant or even a function.
#
# ### 3. **Define the Mesh and Boundaries:**
#    Ensure that your mesh has the boundaries defined where you want to apply the Dirichlet boundary condition. This is typically done in the `Mesh` block.
#
#    ```yaml
#    [Mesh]
#      type = GeneratedMesh
#      dim = 2
#      nx = 10
#      ny = 10
#      xmin = 0
#      xmax = 1
#      ymin = 0
#      ymax = 1
#    []
#    ```
#
#    In this example, the boundaries `left`, `right`, `bottom`, and `top` are automatically generated.
#
# ### 4. **Run the Simulation:**
#    Once everything is set up, you can run the simulation using the MOOSE executable.
#
# ### Example Input File:
#
# ```yaml
# [Mesh]
#   type = GeneratedMesh
#   dim = 2
#   nx = 10
#   ny = 10
#   xmin = 0
#   xmax = 1
#   ymin = 0
#   ymax = 1
# []
#
# [Variables]
#   [u]
#     order = FIRST
#     family = LAGRANGE
#   []
# []
#
# [Kernels]
#   [diff]
#     type = Diffusion
#     variable = u
#   []
# []
#
# [BCs]
#   [left]
#     type = DirichletBC
#     variable = u
#     boundary = left
#     value = 0
#   []
#   [right]
#     type = DirichletBC
#     variable = u
#     boundary = right
#     value = 1
#   []
# []
#
# [Executioner]
#   type = Steady
#   solve_type = 'PJFNK'
# []
#
# [Outputs]
#   exodus = true
# []
# ```
#
# In this example, a Dirichlet boundary condition is applied to the `left` boundary with a value of `0` and to the `right` boundary with a value of `1`.
#
# ### Additional Notes:
# - **Multiple Boundaries:** You can apply the same boundary condition to multiple boundaries by specifying a list of boundaries in the `boundary` parameter.
# - **Non-zero Values:** If you want to enforce a non-zero value, you can simply change the `value` parameter.
# - **Function Values:** If you want to enforce a spatially or temporally varying value, you can use a `Function` object and specify it in the `value` parameter.
#
# For more detailed information, you can refer to the MOOSE documentation or look at specific examples in the MOOSE repository.
# Assistant: {"App_name": "VectorFunctionDirichletBC", "description": "`VectorFunctionDirichletBC` is a generalization of [`VectorDirichletBC`](/VectorDirichletBC.md) which\nimposes possibly temporally- and spatially-dependent values for the Lagrange\nvector components through\nMOOSE [`Function`](/Functions/index.md) objects on degrees of freedom\nthat fall on the boundary defined by the `boundary` parameter. That is, for a\nPDE of the form\n\n\\begin{equation}\n\\begin{aligned}\n-\\nabla^2 \\vec{u} &= \\vec{f} && \\quad \\in \\Omega \\\\\n\\vec{u} &= \\vec{g(t,\\vec{x})} && \\quad \\in \\partial \\Omega_D \\\\\n\\frac{\\partial \\vec{u}}{\\partial n} &= \\vec{h(t,\\vec{x})} && \\quad \\in \\partial \\Omega_N\n\\end{aligned}\n\\end{equation}\n\nwhere $\\Omega \\subset \\mathbb{R}^n$ is the domain, and $\\partial\n\\Omega = \\partial \\Omega_D \\cup \\partial \\Omega_N$ is its boundary.\nA `VectorFunctionDirichletBC` object can be used to impose the\ncondition (2) if the function is well-defined for $\\vec{x} \\in\n\\partial \\Omega_D$. In this case, the `function_x`, `function_y`, and `function_z` parameters correspond to a\nset of MOOSE `Function` objects which represent the mathematical function\n$\\vec{g(t,\\vec{x})}$, and the user must define one or more sidesets\ncorresponding to the boundary subset $\\partial \\Omega_D$ via the\n`boundary` parameter.", "document": "# \"Imposes the essential boundary condition $\\\\vec{u}=\\\\vec{g}$, where $\\\\vec{g}$ components are\n# calculated with functions.\"\nabsolute_value_vector_tags = (no_default)              # \"The tags for the vectors this residual\n# object should fill with the absolute value\n# of the residual contribution\"\n# Group: \"Tagging\"\nboundary                   = (required)                # \"The list of boundary IDs from the mesh\n# where this object applies\"\n# Group: \"\"\ncontrol_tags               = (no_default)              # \"Adds user-defined labels for accessing\n# object parameters via control logic.\"\n# Group: \"Advanced\"\ndiag_save_in               = (no_default)              # \"The name of auxiliary variables to save\n# this BC's diagonal jacobian contributions\n# to.  Everything about that variable must\n# match everything about this variable (the\n# type, what blocks it's on, etc.)\"\n# Group: \"\"\ndisplacements              = (no_default)              # \"The displacements\"\n# Group: \"\"\nenable                     = 1                         # \"Set the enabled status of the MooseObject.\"\n# Group: \"Advanced\"\nextra_matrix_tags          = (no_default)              # \"The extra tags for the matrices this Kernel\n# should fill\"\n# Group: \"Tagging\"\nextra_vector_tags          = (no_default)              # \"The extra tags for the vectors this Kernel\n# should fill\"\n# Group: \"Tagging\"\nfunction                   = (no_default)              # \"The boundary condition vector function.\n# This cannot be supplied with the component\n# parameters.\"\n# Group: \"\"\nfunction_x                 = 0                         # \"The function for the x component\"\n# Group: \"\"\nfunction_y                 = 0                         # \"The function for the y component\"\n# Group: \"\"\nfunction_z                 = 0                         # \"The function for the z component\"\n# Group: \"\"\nimplicit                   = 1                         # \"Determines whether this object is calculated\n# using an implicit or explicit form\"\n# Group: \"Advanced\"\nmatrix_tags                = 'system time'             # \"The tag for the matrices this Kernel should\n# fill\"\n# Group: \"Tagging\"\nsave_in                    = (no_default)              # \"The name of auxiliary variables to save\n# this BC's residual contributions to.  Everything\n# about that variable must match everything\n# about this variable (the type, what blocks\n# it's on, etc.)\"\n# Group: \"\"\nseed                       = 0                         # \"The seed for the  ...
#
# {"App_name": "ADFunctionDirichletBC", "description": "`ADFunctionDirichletBC` is a generalization of [`DirichletBC`](/DirichletBC.md) which\nimposes a possibly temporally- and spatially-dependent value defined\nby a MOOSE [`Function`](/Functions/index.md) object on a particular set of degrees of freedom\n(DOFs) defined by the `boundary` parameter. That is, for a\nPDE of the form\n\n\\begin{equation}\n\\begin{aligned}\n-\\nabla^2 u &= f && \\quad \\in \\Omega \\\\\nu &= g(t,\\vec{x}) && \\quad \\in \\partial \\Omega_D \\\\\n\\frac{\\partial u}{\\partial n} &= h(t,\\vec{x}) && \\quad \\in \\partial \\Omega_N\n\\end{aligned}\n\\end{equation}\n\nwhere $\\Omega \\subset \\mathbb{R}^n$ is the domain, and $\\partial\n\\Omega = \\partial \\Omega_D \\cup \\partial \\Omega_N$ is its boundary,\na `ADFunctionDirichletBC` object can be used to impose the\ncondition (2) if the function is well-defined for $\\vec{x} \\in\n\\partial \\Omega_D$. In this case, the `function` parameter corresponds to a\nMOOSE `Function` object which represents the mathematical function\n$g(t,\\vec{x})$, and the user must define one or more sidesets\ncorresponding to the boundary subset $\\partial \\Omega_D$ via the\n`boundary` parameter.\n\nNote that `ADFunctionDirichletBC` computes its Jacobian using automatic differentiation.\n\n\nWith the parameter `preset = true`, the value of the boundary condition is applied\nbefore the solve begins. With `preset = false`, the boundary condition is\nonly enforced as the solve progresses. In most situations, presetting the boundary\ncondition is better.", "document": "# \"Imposes the essential boundary condition $u=g$, where $g$ is calculated by a function.\"\nabsolute_value_vector_tags = (no_default)          # \"The tags for the vectors this residual object\n# should fill with the absolute value of the\n# residual contribution\"\n# Group: \"Tagging\"\nboundary                   = (required)            # \"The list of boundary IDs from the mesh where\n# this object applies\"\n# Group: \"\"\ncontrol_tags               = (no_default)          # \"Adds user-defined labels for accessing object\n# parameters via control logic.\"\n# Group: \"Advanced\"\ndiag_save_in               = (no_default)          # \"The name of auxiliary variables to save this\n# BC's diagonal jacobian contributions to.  Everything\n# about that variable must match everything about\n# this variable (the type, what blocks it's on,\n# etc.)\"\n# Group: \"\"\ndisplacements              = (no_default)          # \"The displacements\"\n# Group: \"\"\nenable                     = 1                     # \"Set the enabled status of the MooseObject.\"\n# Group: \"Advanced\"\nextra_matrix_tags          = (no_default)          # \"The extra tags for the matrices this Kernel\n# should fill\"\n# Group: \"Tagging\"\nextra_vector_tags          = (no_default)          # \"The extra tags for the vectors this Kernel\n# should fill\"\n# Group: \"Tagging\"\nfunction                   = 0                     # \"The function describing the Dirichlet condition\"\n# Group: \"\"\nimplicit                   = 1                     # \"Determines whether this object is calculated\n# using an implicit or explicit form\"\n# Group: \"Advanced\"\nmatrix_tags                = 'system time'         # \"The tag for the matrices this Kernel should\n# fill\"\n# Group: \"Tagging\"\npreset                     = 1                     # \"Whether or not to preset the BC (apply the\n# value before the solve begins).\"\n# Group: \"\"\nsave_in                    = (no_default)          # \"The name of auxiliary variables to save this\n# BC's residual contributions to.  Everything\n# about that variable must match everything about\n# this variable (the type, what blocks it's on,\n# etc.)\"\n# Group: \"\"\nseed                       = 0                     # \"The seed for the master random number generator\"\n# Group: \"Advanced\"\ntype                       = ADFunctionDirichletBC # \"\"\n# Gro ...
#
# {"App_name": "FunctionDirichletBC", "description": "`FunctionDirichletBC` is a generalization of [`DirichletBC`](/DirichletBC.md) which\nimposes a possibly temporally- and spatially-dependent value defined\nby a MOOSE [`Function`](/Functions/index.md) object on a particular set of degrees of freedom\n(DOFs) defined by the `boundary` parameter. That is, for a\nPDE of the form\n\n\\begin{equation}\n\\begin{aligned}\n-\\nabla^2 u &= f && \\quad \\in \\Omega \\\\\nu &= g(t,\\vec{x}) && \\quad \\in \\partial \\Omega_D \\\\\n\\frac{\\partial u}{\\partial n} &= h(t,\\vec{x}) && \\quad \\in \\partial \\Omega_N\n\\end{aligned}\n\\end{equation}\n\nwhere $\\Omega \\subset \\mathbb{R}^n$ is the domain, and $\\partial\n\\Omega = \\partial \\Omega_D \\cup \\partial \\Omega_N$ is its boundary,\na `FunctionDirichletBC` object can be used to impose the\ncondition (2) if the function is well-defined for $\\vec{x} \\in\n\\partial \\Omega_D$. In this case, the `function` parameter corresponds to a\nMOOSE `Function` object which represents the mathematical function\n$g(t,\\vec{x})$, and the user must define one or more sidesets\ncorresponding to the boundary subset $\\partial \\Omega_D$ via the\n`boundary` parameter.\n\n\nWith the parameter `preset = true`, the value of the boundary condition is applied\nbefore the solve begins. With `preset = false`, the boundary condition is\nonly enforced as the solve progresses. In most situations, presetting the boundary\ncondition is better.", "document": "# \"Imposes the essential boundary condition $u=g(t,\\\\vec{x})$, where $g$ is a (possibly) time and\n# space-dependent MOOSE Function.\"\nabsolute_value_vector_tags = (no_default)        # \"The tags for the vectors this residual object\n# should fill with the absolute value of the residual\n# contribution\"\n# Group: \"Tagging\"\nboundary                   = (required)          # \"The list of boundary IDs from the mesh where\n# this object applies\"\n# Group: \"\"\ncontrol_tags               = (no_default)        # \"Adds user-defined labels for accessing object\n# parameters via control logic.\"\n# Group: \"Advanced\"\ndiag_save_in               = (no_default)        # \"The name of auxiliary variables to save this\n# BC's diagonal jacobian contributions to.  Everything\n# about that variable must match everything about\n# this variable (the type, what blocks it's on,\n# etc.)\"\n# Group: \"\"\ndisplacements              = (no_default)        # \"The displacements\"\n# Group: \"\"\nenable                     = 1                   # \"Set the enabled status of the MooseObject.\"\n# Group: \"Advanced\"\nextra_matrix_tags          = (no_default)        # \"The extra tags for the matrices this Kernel\n# should fill\"\n# Group: \"Tagging\"\nextra_vector_tags          = (no_default)        # \"The extra tags for the vectors this Kernel should\n# fill\"\n# Group: \"Tagging\"\nfunction                   = (required)          # \"The forcing function.\"\n# Group: \"\"\nimplicit                   = 1                   # \"Determines whether this object is calculated\n# using an implicit or explicit form\"\n# Group: \"Advanced\"\nmatrix_tags                = 'system time'       # \"The tag for the matrices this Kernel should\n# fill\"\n# Group: \"Tagging\"\npreset                     = 1                   # \"Whether or not to preset the BC (apply the value\n# before the solve begins).\"\n# Group: \"\"\nsave_in                    = (no_default)        # \"The name of auxiliary variables to save this\n# BC's residual contributions to.  Everything about\n# that variable must match everything about this\n# variable (the type, what blocks it's on, etc.)\"\n# Group: \"\"\nseed                       = 0                   # \"The seed for the master random number generator\"\n# Group: \"Advanced\"\ntype                       = FunctionDirichletBC # \"\"\n# Group: \"\"\nuse_displaced_mesh         = 0                   # \"Whether or not this object should use the displac ...
# Assistant: In MOOSE, Dirichlet boundary conditions can be defined using several different objects depending on the specific requirements of your simulation. Here are the key objects and how they are used:
#
# ### 1. **`FunctionDirichletBC`**
#    - **Description**: This object imposes a Dirichlet boundary condition where the value is defined by a MOOSE `Function` object. The function can be time- and space-dependent.
#    - **Usage**:
#      - Set the `boundary` parameter to specify the boundary where the condition applies.
#      - Set the `function` parameter to the MOOSE `Function` object that defines the boundary value.
#      - Optionally, set `preset = true` to apply the boundary condition before the solve begins.
#    - **Example**:
#      ```cpp
#      [BCs]
#        [left]
#          type = FunctionDirichletBC
#          variable = u
#          boundary = left
#          function = 'sin(t)'
#        []
#      []
#      ```
#
# ### 2. **`ADFunctionDirichletBC`**
#    - **Description**: Similar to `FunctionDirichletBC`, but it uses automatic differentiation (AD) to compute the Jacobian. This is useful for nonlinear problems.
#    - **Usage**:
#      - Set the `boundary` parameter to specify the boundary.
#      - Set the `function` parameter to the MOOSE `Function` object.
#      - Optionally, set `preset = true` to apply the boundary condition before the solve begins.
#    - **Example**:
#      ```cpp
#      [BCs]
#        [left]
#          type = ADFunctionDirichletBC
#          variable = u
#          boundary = left
#          function = 'sin(t)'
#        []
#      []
#      ```
#
# ### 3. **`VectorFunctionDirichletBC`**
#    - **Description**: This object is used for vector-valued variables. It imposes a Dirichlet boundary condition where each component of the vector is defined by a MOOSE `Function` object.
#    - **Usage**:
#      - Set the `boundary` parameter to specify the boundary.
#      - Set the `function_x`, `function_y`, and `function_z` parameters to the MOOSE `Function` objects that define the components of the vector.
#    - **Example**:
#      ```cpp
#      [BCs]
#        [left]
#          type = VectorFunctionDirichletBC
#          variable = u
#          boundary = left
#          function_x = 'sin(t)'
#          function_y = 'cos(t)'
#          function_z = 't'
#        []
#      []
#      ```
#
# ### Summary
# - Use `FunctionDirichletBC` for scalar variables with a function-defined boundary condition.
# - Use `ADFunctionDirichletBC` for scalar variables when automatic differentiation is needed.
# - Use `VectorFunctionDirichletBC` for vector-valued variables with function-defined boundary conditions.
#
# These objects allow you to define Dirichlet boundary conditions in a flexible and powerful way, accommodating both scalar and vector fields, as well as time- and space-dependent values.
